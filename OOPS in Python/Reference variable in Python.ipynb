# %% [markdown]
# **Reference Variables:**
#
# _Reference variables hold the objects_
#
# 1. We can create objects without reference variable as well
#
# 2. An object can have multiple reference variables
#
# 3. Assigning a new reference variable to an existing object does not create a new object

# %%
from unicodedata import name


# object without a reference :
class person :
    def __init__(self):
        self.name = 'ayush'
        self.gender = 'papa'

person() # we can also do this

# %%
p = person() # p contains the address (reference of the obj.
q = p

# %%
# multiple ref
print(id(p))
print(id(q))
# Out:
# 1569511922640
# 1569511922640

# %%
# change attribute value with the help of 2nd object
print(p.name)
print(q.name)
q.name = 'raju'
print(p.name)
print(q.name)
# Out:
# ayush
# ayush
# raju
# raju

# %% [markdown]
# Pass by reference :

# %%
class person :
    def __init__(self, name, gender):
        self.name = name
        self.gender = gender

# outside the class -> function
def greet(person):
    print(id(person))
    print('hi my name is ', person.name, ' and I am a ', person.gender)

p = person('ayush', 'male')
print(id(p))
greet(p)
# Out:
# 1569515028560
# 1569515028560
# hi my name is  ayush  and I am a  male
