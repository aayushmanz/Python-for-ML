# %% [markdown]
# **User define datatypes using magic methods :**

# %%
# user define data type :
# our class name is fraction
class fraction :
    def __init__(self, num, den): # parameterize constructor !
        self.num = num
        self.den = den

    # arithmetic magic methods :
    def __str__(self): # magic method
        return '{}/{}'.format(self.num,self.den) # we are using format method for structuring out output !
    def __add__(self, other):# other is also a pointer like self  # this also a magic method
        new_num = self.num*other.den + other.num*self.den
        new_den = self.den*other.den
        return '{}/{}'.format(new_num,new_den)

    def __sub__(self, other):# other is also a pointer like self  # this also a magic method
        new_num = self.num*other.den - other.num*self.den
        new_den = self.den*other.den
        return '{}/{}'.format(new_num,new_den)

    def __mul__(self, other):# other is also a pointer like self  # this also a magic method
        new_num = self.num*other.num
        new_den = self.den*other.den
        return '{}/{}'.format(new_num,new_den)
    def __truediv__(self, other):# other is also a pointer like self  # this also a magic method
        new_num = self.den*other.den
        new_den = self.num*other.num
        return '{}/{}'.format(new_num,new_den)

# %%
obj = fraction(1, 2)
obj2 = fraction(2,3)

# %%
print(obj)
# Out:
# 1/2

# %%
print(obj + obj2)
# Out:
# 7/6

# %%
print(obj - obj2)
# Out:
# -1/6

# %%
print(obj * obj2)
# Out:
# 2/6

# %%
print(obj / obj2)
# Out:
# 6/2
