# %%
# super keyword is a way to use the parent class methods and variable values into child class.



# Example :
class phone :
    def __init__(self, price, brand, camera):
        print('Inside phone constructor ')
        self.price = price
        self.brand = brand
        self.camera = camera
    def buy(self):
        print('buying a phone')

class smartphone(phone):
    def buy(self):
        print('buying a smartphone !')
        super().buy()  # calling the phone class buy method !
     #   print(super().brand) -> we cannot access attributes in constructor through the super keyword !

s = smartphone(20000, 'apple', 16)
s.buy()
# Out:
# Inside phone constructor
# buying a smartphone !
# buying a phone

# %%
# we can call super keyword from outside of class !
# s.super().buy() -> no we dont call super outside of class.

# %%
# super -> constructor :
class phone:
    def __init__(self, price, brand, camera):
        print('inside phone constructor !')
        self.__price = price
        self.brand = brand
        self.camera = camera

class smartphone(phone) :
    def __init__(self,price, brand, camera, os, ram):
        super().__init__(price, brand, camera)  # accessing the upper phone class constructor through super() class.
        self.os = os
        self.ram = ram
        print('inside smartphone constructor ! ')

s = smartphone(20000, 'samsung',12, 'android', 2)

print(s.os)
print(s.brand)
# Out:
# inside phone constructor !
# inside smartphone constructor !
# android
# samsung
