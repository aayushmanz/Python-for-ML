# %% [markdown]
# 1. **Write OOP classes to handle the following scenarios:**
#
# A user can create and view 2D coordinates
#
# A user can find out the distance between 2 coordinates
#
# A user can find the distance of a coordinate from origin
#
# A user can check if a point lies on a given line
#
# A user can find the distance between a given 2D point and a given line

# %%
from itertools import count


class point :
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __str__(self):
        return "<{},{}>".format(self.x, self.y)

    def euclidean_distance(self,other):
        return ((self.x - other.x)**2+(self.y - other.y)**2)**0.5

    def distrance_from_origin(self):
        #return(self.x**2 + self.y**2)**0.5
        return self.euclidean_distance(point(0,0))

# %%
p1 = point(0,0)
p2 = point(1,1)
# <x,y>
p1.euclidean_distance(p2)
p1.distrance_from_origin()
# Out:
# 0.0

# %%
class line:

    def __init__(self,a,b,c):
        self.a = a
        self.b = b
        self.c = c

    def __str__(self):
        return '{}x + {}y +{} = 0'.format(self.a, self.b, self.c)

    def point_on_line(line,point):
        if line.a*point.x + line.b*point.y + line.c == 0:
            return 'lies on the line'
        else :
            return 'does not lies on the line'
    def shortest_distance(line,point):
        abs(line.a*point.x + line.b * point.y + line.c)/(line.a**2 + line.b**2)

# %%
l = line(1,1,-2)
p1 = point(1,1)
print(l)
print(p1)
# Out:
# 1x + 1y +-2 = 0
# <1,1>

# %%
l.point_on_line(p1)
# Out:
# 'lies on the line'

# %%
print(l.shortest_distance(p1))
# Out:
# None

# %%
# one more easy and better Example :
class person :
    def __init__(self, name, country):
        self.name = name
        self.country = country

    def greet(self):
        if self.country == 'india':
            print('namaste', self.name)
        else :
            print('Hello Angreez',self.name)

# %%
# how to access attributes :
if __name__ == '__main__':
   p = person('ayush','india')
   p.greet()
# Out:
# namaste ayush

# %%
p.name
# Out:
# 'ayush'

# %%
p.country
# Out:
# 'india'

# %%
p.gender = 'male' # we can also create object outside the class.

# %%
p.gender
# Out:
# 'male'
