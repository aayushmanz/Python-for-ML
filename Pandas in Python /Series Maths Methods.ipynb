# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushmanz/Python-for-ML/blob/colab/Series%20Maths%20Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Series Maths Methods :**

# %%
import pandas as pd
import numpy as np

vk = pd.read_csv("/content/kohli_ipl.csv")
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
# count :
vk.count()
# Out:
# match_no    215
# runs        215
# dtype: int64

# %%
# Sum -> Product

subs = pd.read_csv("/content/subs.csv")

subs.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
subs.product()
# Out:
# Subscribers gained    0
# dtype: int64

# %%
# Means -> median -> mode -> std -> var

subs.mean()
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
print(vk.median())
# Out:
# match_no    108.0
# runs         24.0
# dtype: float64

# %%
movies = pd.read_csv("/content/bollywood.csv")['lead']
print(movies.mode())
# Out:
# 1

# %%
subs.std()
# Out:
# Subscribers gained    62.675023
# dtype: float64

# %%
vk.var()
# Out:
# match_no    3870.000000
# runs         688.002478
# dtype: float64

# %%
# Min / max :

subs.max() # Max subscibers count day !
# Out:
# Subscribers gained    396
# dtype: int64

# %%
subs.min() # Min subscibers count day !
# Out:
# Subscribers gained    33
# dtype: int64

# %%
# describe :

print(vk.describe()) # mathmetical summary
# Out:
#          match_no        runs
# count  215.000000  215.000000
# mean   108.000000   30.855814
# std     62.209324   26.229801
# min      1.000000    0.000000
# 25%     54.500000    9.000000
# 50%    108.000000   24.000000
# 75%    161.500000   48.000000
# max    215.000000  113.000000
