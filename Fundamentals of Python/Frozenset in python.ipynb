# %%
# create Frozenset
fs = frozenset([1,2,3])
fs2 = frozenset([3,4,5])

fs | fs2
# Out:
# frozenset({1, 2, 3, 4, 5})
# frozenset({1, 2, 3, 4, 5})

# %%
# 2D sets :
fs = frozenset([1,2,frozenset([3,4])])
print(fs)
# Out:
# frozenset({frozenset({3, 4}), 1, 2})

# %%
# Example :
{i**2 for i in range(1,11) if i > 5}
# Out:
# {36, 49, 64, 81, 100}
