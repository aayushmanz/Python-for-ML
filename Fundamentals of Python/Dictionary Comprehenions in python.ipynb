# %% [markdown]
# Dictionary Comprehension :
#
#
# {key : value for vars in iterable }

# %%
# print 1st 10 number and their squares :
{i:i**2 for i in range(1,11)}
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
# using existing dict :
dist = {'delhi' : 1000,
        'mumbai': 2000,
        'jaipur' : 3000
        }
print(dist.items())
# Out:
# dict_items([('delhi', 1000), ('mumbai', 2000), ('jaipur', 3000)])

# %%
# using existing dict :
dist = {'delhi' : 1000,
        'mumbai': 2000,
        'jaipur' : 3000
        }
{key:value*0.62 for (key,value) in dist.items()}
# Out:
# {'delhi': 620.0, 'mumbai': 1240.0, 'jaipur': 1860.0}

# %%
# using zip :
days = {'sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'Friday', 'saturday'}
temp = {30.5, 32.4, 31.4}
{i:j for (i , j) in zip(days,temp)}
# Out:
# {'thursday': 32.4, 'wednesday': 30.5, 'tuesday': 31.4}

# %%
# using if condition
products = {'phone':10, 'laptop':0,'charger':32, 'tablet':0}
{key : value for (key, value) in products.items() if value > 0}
# Out:
# {'phone': 10, 'charger': 32}

# %%
# nested comprehension
# print tables of numbers from 2 to 4
{i:{j:i*j for j in range(1,11)} for i in range(2,5)}
# Out:
# {2: {1: 2, 2: 4, 3: 6, 4: 8, 5: 10, 6: 12, 7: 14, 8: 16, 9: 18, 10: 20},
#  3: {1: 3, 2: 6, 3: 9, 4: 12, 5: 15, 6: 18, 7: 21, 8: 24, 9: 27, 10: 30},
#  4: {1: 4, 2: 8, 3: 12, 4: 16, 5: 20, 6: 24, 7: 28, 8: 32, 9: 36, 10: 40}}

# %%
{
    2:{1:2,2:4,3:6,4:8},
    3:{1:3,2:6,3:9,4:12},
    4:{1:4,2:8,3:12,4:16}
}
