# %%
# Modules in Python
# 1. math
# 2. keywords
# 3. constants
# 4. random
# 5. datetime

# -> Modules jo pehele se hi bane hue code ko reuse karna !

# %%
# Math
import math


print(math.factorial(5))

print(math.floor(9.6))

print(math.sqrt(5))
# Out:
# 120
# 9
# 2.23606797749979

# %%
# keywords
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Random
import random

print(random.randint(1,100))
# Out:
# 48

# %%
# datetime

import datetime

print(datetime.datetime.now())
print(datetime.time.min)
# Out:
# 2026-02-12 12:55:04.255893
# 00:00:00

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             _tokenize           hmac                pygments
# __future__          _tracemalloc        html                queue
# __hello__           _typing             http                quopri
# __phello__          _uuid               idlelib             random
# _abc                _warnings           idna                re
# _aix_support        _weakref            imaplib             reprlib
# _android_support    _weakrefset         importlib           requests
# _apple_support      _winapi             inspect             rlcompleter
# _ast                _wmi                interpreterInfo     runfiles
# _asyncio            _zoneinfo           io                  runpy
# _bisect             abc                 ipaddress           sched
# _blake2             aiohappyeyeballs    ipykernel           secrets
# _bz2                aiohttp             ipykernel_launcher  select
# ...
