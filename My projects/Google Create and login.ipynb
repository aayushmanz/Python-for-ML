# %%
import json
class CreateAndLogs:

    def Create(self, fname, lname, email, password, device, secret_info):

        user_account__ = {
            'name' : fname + ' ' + lname,
            'email' : email,
            'password' : password,
            'device' : device,
            'secret_info' : secret_info
        }


        with open('User_info.json', 'w') as f:
            json.dump(user_account__, f, indent=4)

        self.login(device)

    def login(self, user_device):

        print("Logging in :")
        email = input("Enter your email address: ")
        password = input("Enter your password: ")
        device = input("""Enter your device name for Confirmation :
                 1. Android
                 2. IOS
                 3. Windows
                 4. linux
                 5. MacOS
        """)
        if device == '1':
            user_device = 'Android'
        elif device == '2':
            user_device = 'IOS'
        elif device == '3':
            user_device = 'Windows'
        elif device == '4':
            user_device = 'Linux'
        elif device == '5':
            user_device = 'MacOS'
        else:
            print("Invaild choice !")
            self.login(user_device)
        try:
         with open('User_info.json', 'r') as f:
            saved_user = json.load(f)

         if saved_user['email'] == email and password == saved_user['password']:
             if saved_user['device'] != user_device:
               print("This is not Your device we detect that, So now you need to give some Secret Answers !")
               secret_ques = input("""
               1. What is Your best friend and girl friend name ?
               2. What is your fav sports ?
               3. What is Fav color ?
               4. What is Your favorite destination ?
               5. Who is Your fav father ? ( just for fun )
               """)

               if secret_ques == '1' or secret_ques == '2':
                   if secret_ques == '1':
                       secret_info = input("What is Your best friend and girl friend name ? : ")
                       if saved_user['secret_info'] == secret_info:
                           print('User Authentication is successful !')
                           self.search()
                       else :
                           print(f"Bro sorry but You are not Lord {saved_user['name']}")
                           print(f'Sorry But You are not Authorized !')
                   else :
                       secret_info = input('What is your fav sports ? : ')
                       if saved_user['secret_info'] == secret_info:
                           print('User Authentication is successful !')
                           self.search()
                       else :
                           print(f"Bro sorry but You are not Lord {saved_user['name']}")
                           print(f'Sorry But You are not Authorized !')
               elif secret_ques == '3' or secret_ques == '4':
                   if secret_ques == '3':
                       secret_info = input("What is Fav color ? : ")
                       if saved_user['secret_info'] == secret_info:
                           print('User Authentication is successful !')
                           self.search()
                       else :
                           print(f"Bro sorry but You are not Lord {saved_user['name']}")
                           print(f'Sorry But You are not Authorized !')
                   else :
                       secret_info = input('What is Your favorite destination ?')
                       if saved_user['secret_info'] == secret_info:
                           print('User Authentication is successful !')
                           self.search()
                       else :
                           print(f"Bro sorry but You are not Lord {saved_user['name']}")
                           print(f'Sorry But You are not Authorized !')
               elif secret_ques == '5':
                   secret_info = input('Who is Your fav father ? ( just for fun ) : ')
                   if saved_user['secret_info'] == secret_info:
                           print('User Authentication is successful !')
                           self.search()
                   else :
                           print(f"Bro sorry but You are not Lord {saved_user['name']}")
                           print(f'Sorry But You are not Authorized !')
        except Exception as e:
            print(e)
        finally:
            print("Dear user never share Your OTP with anyone !")

    def search(self):
        print('Welcome !, bro aage idea nhi aara ! ')



class Google(CreateAndLogs):
    def __init__(self, fname, lname, email, password, device, secret_info):

        self.fname = fname
        self.lname = lname
        self.email = email
        self.password = password
        self.device = device
        self.secret_info = secret_info

        self.Create(self.fname, self.lname, self.email, self.password, self.device, self.secret_info)
        print("Your account as been Created Successfully !")

# %%
if __name__ == '__main__':
  try:
    fname = input("Enter your First Name : ")
    lname = input("Enter the last name :")
    email = input("Enter Your Email address : ")
    password = input("Create Your password : ")
    device = input("""What is your device name :
        1. Android
        2. IOS
        3. Windows
        4. linux
        5. MacOS
    """)
    user_device = ''
    if device == '2' or device == '5':
        print("Paise wali party !!!!!")
        print(f'Welcome Apple User, {fname + lname} !')
        if device == '2':
          user_device = 'IOS'
        else :
          user_device = 'MacOS'
    elif device == '1' or device == '3':
        print('Ohhh Aam Admi hoooo !')
        if device == '1':
          print(f'Welcome Android User, {fname + lname} !')
          user_device = 'Android'
        else :
            print(f'Welcome Windows PC User, {fname + lname} !')
            user_device = 'Windows'
    elif device == '4':
        print('Hacker aagya bhai logo !')
        print(f'Welcome Linux PC User, {fname + lname} !')
        user_device = 'Linux'
    else :
        print('Enter the valid choice !')

    print("Suggest your secret for User Authentication : ")
    secret_ques = input("""
        1. What is best friend / girl friend name ?
        2. What is your fav sports ?
        3. What is Fav color ?
        4. What is Your favorite destination ?
        5. Who is Your fav father ? ( just for fun )
    """)
    secret_info = ''
    if secret_ques == '1':
        secret_info = input('Best friend or Girl friend name : ')
    elif secret_ques == '2':
        secret_info = input("Enter your fav sport : ")
    elif secret_ques == '3':
        secret_info = input("Enter Fav Color : ")
    elif secret_ques == '4':
        secret_info = input("Enter your fav destination : ")
    elif secret_ques == '5':
        secret_info = input("Enter your fav Father ( just for fun ) : ")
    else :
        print('invalid choice !')

    user = Google(fname, lname, email, password, user_device, secret_info)
  except KeyboardInterrupt as e:
       print("Bro please Please respect my code !")
# Out:
# Ohhh Aam Admi hoooo !
# Welcome Android User, ayusuthar !
# Suggest your secret for User Authentication :
# Logging in :
# This is not Your device we detect that, So now you need to give some Secret Answers !
# User Authentication is successful !
# Welcome !, bro aage idea nhi aara !
# Dear user never share Your OTP with anyone !
# Your account as been Created Successfully !
