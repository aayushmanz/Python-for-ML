# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/imdb-top-1000.csv')

# %%
movies.head(1)
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
#
#          Director        Star1  No_of_Votes       Gross  Metascore
# 0  Frank Darabont  Tim Robbins      2343110  28341469.0       80.0

# %%
genres = movies.groupby('Genre')
genres.min()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                                 300          1924       45
# Adventure            2001: A Space Odyssey          1925       88
# Animation                            Akira          1940       71
# Biography                 12 Years a Slave          1928       93
# Comedy                (500) Days of Summer          1921       68
# Crime                         12 Angry Men          1931       80
# Drama                                 1917          1925       64
# Family          E.T. the Extra-Terrestrial          1971      100
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                Shadow of a Doubt          1941      100
# Horror                               Alien          1933       71
# Mystery                          Dark City          1938       96
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
# applying builtin aggreggation functioon groupby objects

# %%
# find the top 3 genre by total earning.
gen =movies.groupby('Genre')
gen['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# one more way :
movies.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# find the top 3 Highest Gross by total earning.
gross = movies.groupby('Gross')
gross.max().head(3)
# Out:
#                      Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# Gross
# 1305.0                Adams æbler          2005       94  Comedy          7.8
# 3296.0  Knockin' on Heaven's Door          1997       87  Action          8.0
# 3600.0                 Mr. Nobody          2009      141   Drama          7.8
#
#                     Director           Star1  No_of_Votes  Metascore
# Gross
# 1305.0  Anders Thomas Jensen  Ulrich Thomsen        45717       51.0
# 3296.0           Thomas Jahn   Til Schweiger        27721        NaN
# 3600.0      Jaco Van Dormael      Jared Leto       216421       63.0

# %%
# find the genre with highest average IMDB rating. 

movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False).head(3)
# Out:
# Genre
# Western    8.350000
# Crime      8.016822
# Fantasy    8.000000
# Name: IMDB_Rating, dtype: float64

# %%
# find numbers of movies done by each actor 
movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks            12
# Robert De Niro       11
# Clint Eastwood       10
# Al Pacino            10
# Leonardo DiCaprio     9
#                      ..
# Gérard Jugnot         1
# Günes Sensoy          1
# Haluk Bilginer        1
# Harriet Andersson     1
# Graham Chapman        1
# Name: Series_Title, Length: 660, dtype: int64

# %%
# find dirctor with most popularity.
movies.groupby('Director')['Metascore'].mean().sort_values(ascending=False).head(1)
# Out:
# Director
# Orson Welles    99.5
# Name: Metascore, dtype: float64

# %%
movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
# find the highest rated movies of each genre.

movies.groupby('Genre')['IMDB_Rating'].max().sort_values(ascending=False)
# Out:
# Genre
# Drama        9.3
# Crime        9.2
# Action       9.0
# Biography    8.9
# Western      8.8
# Adventure    8.6
# Comedy       8.6
# Animation    8.6
# Horror       8.5
# Mystery      8.4
# Fantasy      8.1
# Film-Noir    8.1
# Family       7.8
# Thriller     7.8
# Name: IMDB_Rating, dtype: float64

# %%
# Groupby Attributes and methods
# find total numbers of Groups -> len
# find items in each group -> size
# first()/last() -> nth items
# get_group -> vs filtering 
# groups 
# describe
# sample 
# nunique

# %%
# len(): 
len(movies.groupby('Genre'))
# Out:
# 14

# %%
movies['Genre'].nunique() # we can also do that
# Out:
# 14

# %%
# size()

movies.groupby('Genre').size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
# first(): 

genres = movies.groupby('Genre')
genres.first() # all genres first movies data we can find through this.
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                     The Dark Knight          2008      152
# Adventure                     Interstellar          2014      169
# Animation    Sen to Chihiro no kamikakushi          2001      125
# Biography                 Schindler's List          1993      195
# Comedy                        Gisaengchung          2019      132
# Crime                        The Godfather          1972      175
# Drama             The Shawshank Redemption          1994      142
# Family          E.T. the Extra-Terrestrial          1982      115
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                    The Third Man          1949      104
# Horror                              Psycho          1960      109
# Mystery                            Memento          2000      113
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
# last():
genres.last()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
# nth -> shows every movies according its number of row arrangment movie.

genres.nth(6) # seventh movie fo index
# Out:
#                                        Series_Title Released_Year  Runtime  \
# 16   Star Wars: Episode V - The Empire Strikes Back          1980      124
# 27                                            Se7en          1995      127
# 32                            It's a Wonderful Life          1946      130
# 66                                           WALL·E          2008       98
# 83                               The Great Dictator          1940      125
# 102                                      Braveheart          1995      178
# 118                              North by Northwest          1959      136
# 420                                          Sleuth          1972      138
# 724                                         Get Out          2017      104
#
#          Genre  IMDB_Rating              Director             Star1  \
# 16      Action          8.7        Irvin Kershner       Mark Hamill
# 27       Crime          8.6         David Fincher    Morgan Freeman
# ...

# %%
# get_group :
genres.get_group(name='Horror').head()
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho          1960      109  Horror          8.5
# 75                      Alien          1979      117  Horror          8.4
# 271                 The Thing          1982      109  Horror          8.1
# 419              The Exorcist          1973      122  Horror          8.0
# 544  Night of the Living Dead          1968       96  Horror          7.9
#
#              Director             Star1  No_of_Votes        Gross  Metascore
# 49   Alfred Hitchcock   Anthony Perkins       604211   32000000.0       97.0
# 75       Ridley Scott  Sigourney Weaver       787806   78900000.0       89.0
# 271    John Carpenter      Kurt Russell       371271   13782838.0       57.0
# 419  William Friedkin     Ellen Burstyn       362393  232906145.0       81.0
# 544  George A. Romero       Duane Jones       116557      89029.0       89.0

# %%
# other way :
movies[movies['Genre'] == 'Horror'].head()
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho          1960      109  Horror          8.5
# 75                      Alien          1979      117  Horror          8.4
# 271                 The Thing          1982      109  Horror          8.1
# 419              The Exorcist          1973      122  Horror          8.0
# 544  Night of the Living Dead          1968       96  Horror          7.9
#
#              Director             Star1  No_of_Votes        Gross  Metascore
# 49   Alfred Hitchcock   Anthony Perkins       604211   32000000.0       97.0
# 75       Ridley Scott  Sigourney Weaver       787806   78900000.0       89.0
# 271    John Carpenter      Kurt Russell       371271   13782838.0       57.0
# 419  William Friedkin     Ellen Burstyn       362393  232906145.0       81.0
# 544  George A. Romero       Duane Jones       116557      89029.0       89.0

# %%
# groups():

genres.groups # this will shows dictionary of our database.
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
# describe():

genres.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
# sample():

genres.sample().head(5)
# Out:
#                Series_Title Released_Year  Runtime      Genre  IMDB_Rating  \
# 569           The Gentlemen          2019      113     Action          7.8
# 110                Das Boot          1981      149  Adventure          8.3
# 146                      Up          2009       96  Animation          8.2
# 606  Straight Outta Compton          2015      147  Biography          7.8
# 500              C.R.A.Z.Y.          2005      129     Comedy          7.9
#
#               Director                Star1  No_of_Votes        Gross  \
# 569        Guy Ritchie  Matthew McConaughey       237392  179413519.0
# 110  Wolfgang Petersen      Jürgen Prochnow       231855   11487676.0
# 146        Pete Docter         Bob Peterson       935507  293004164.0
# 606       F. Gary Gray   O'Shea Jackson Jr.       179264  161197785.0
# 500   Jean-Marc Vallée          Michel Côté        31476  527282774.0
#
#      Metascore
# 569       51.0
# 110       86.0
# 146       88.0
# 606       72.0
# ...

# %%
# nunique() :

genres.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...
