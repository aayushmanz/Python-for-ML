# %%
import pandas as pd

ipl = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/ipl-matches.csv')
ipl.iloc[0:80]
# Out:
#          ID       City        Date Season  MatchNumber  \
# 0   1312200  Ahmedabad  2022-05-29   2022        Final
# 1   1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2   1312198    Kolkata  2022-05-25   2022   Eliminator
# 3   1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4   1304116     Mumbai  2022-05-22   2022           70
# ..      ...        ...         ...    ...          ...
# 75  1254116    Sharjah  2021-10-13   2021  Qualifier 2
# 76  1254115    Sharjah  2021-10-11   2021   Eliminator
# 77  1254114      Dubai  2021-10-10   2021  Qualifier 1
# 78  1254101      Dubai  2021-10-08   2021           56
# 79  1254088  Abu Dhabi  2021-10-08   2021           55
#
#                           Team1                        Team2  \
# 0              Rajasthan Royals               Gujarat Titans
# 1   Royal Challengers Bangalore             Rajasthan Royals
# 2   Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# find all the final winners

mask = ipl['MatchNumber']== 'Final'

new_df =  ipl[mask]

new_df[['Season', 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl[ipl['MatchNumber']=='Final'][['Season','WinningTeam']] # short way.
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over finishers have occured
ipl[ipl['SuperOver']=='Y'][['SuperOver','WinningTeam']]
# Out:
#     SuperOver                  WinningTeam
# 114         Y               Delhi Capitals
# 158         Y        Kolkata Knight Riders
# 159         Y              Kings XI Punjab
# 184         Y  Royal Challengers Bangalore
# 192         Y               Delhi Capitals
# 203         Y               Mumbai Indians
# 244         Y               Delhi Capitals
# 339         Y               Mumbai Indians
# 474         Y              Kings XI Punjab
# 533         Y             Rajasthan Royals
# 608         Y  Royal Challengers Bangalore
# 621         Y          Sunrisers Hyderabad
# 819         Y              Kings XI Punjab
# 883         Y             Rajasthan Royals

# %%
ipl[ipl['SuperOver']=='Y'][['SuperOver','WinningTeam']].shape[0]
# shape is use for finding the total number of matches are occur in ipl ( super overs )
# Out:
# 14

# %%
# how many matches has csk won in kolkata

ipl[ipl['City']=='Kolkata'][ipl['WinningTeam']=='Chennai Super Kings'].shape[0]

# this is tried by me !
# Out:
# /tmp/ipykernel_1980/1379285332.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ipl[ipl['City']=='Kolkata'][ipl['WinningTeam']=='Chennai Super Kings'].shape[0]
# 5

# %%
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')][['Team2','City']].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in  percentage
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes > 10000

movies =  pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/movies.csv')

movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movies[(movies['imdb_rating']>8)&(movies['imdb_votes']>10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7.5 %

# important Question for understand 
# using Lambda in Filtering the data !
movies[(movies['genres'].str.split('|').apply(lambda x : 'Action' in x))&(movies['imdb_rating']>7.5)].shape[0]
# Out:
# 33

# %%
movies[(movies['genres'].str.contains('Action'))&(movies['imdb_rating']>7.5)].shape[0]

# this is the second way by using Contain()
# Out:
# 33

# %%
#  Write a function that can return the track record of  2 teams against each other.

# %% [markdown]
# **2. Adding new cols :**

# %%
# completely new 
movies['Country']='India' # we can add new cols too.

movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
# from existing ones :
movies.dropna(inplace=True)

# %%
movies['Lead Actor']=movies['actors'].str.split('|').apply(lambda x : x[0])
movies.set_index('Lead Actor').head(2)
# Out:
#                      title_x    imdb_id  \
# Lead Actor
# Ranveer Singh      Gully Boy  tt2395469
# Gavie Chahal   Yeh Hai India  tt5525846
#
#                                                      poster_path  \
# Lead Actor
# Ranveer Singh  https://upload.wikimedia.org/wikipedia/en/thum...
# Gavie Chahal   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                  wiki_link        title_y  \
# Lead Actor
# Ranveer Singh      https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# Gavie Chahal   https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
#
#               original_title  is_adult  year_of_release runtime  \
# Lead Actor
# Ranveer Singh      Gully Boy         0             2019     153
# Gavie Chahal   Yeh Hai India         0             2017     128
#
#                                genres  imdb_rating  imdb_votes  \
# Lead Actor
# Ranveer Singh             Drama|Music          8.2       22440
# ...

# %% [markdown]
# **3. Important** DataFrames Functions**

# %%
# astype

ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info() # now our datatype of id is now int32
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
ipl['Season']=ipl['Season'].astype('category')
ipl['Team1']=ipl['Team1'].astype('category')
ipl['Team2']=ipl['Team2'].astype('category')

# %%
ipl.info() # now our season dataype is category
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
# ...

# %%
# value_counts

# %%
# find which player has won most potm => in finals and Qualifiers.

# %%
# toss decision plot

# %%
# how many matches each team has played

# %%
# Sort_values -> na_position -> inplace -> Multipl cols
