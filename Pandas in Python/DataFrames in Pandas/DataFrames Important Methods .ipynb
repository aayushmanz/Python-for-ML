# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **More Important Functions / methods :**

# %%
# value_counts
# sort_values
# rank
# sort_index
# set_index
# rename index -> rename
# reset_index
# unique & nunique
# isnull/notnull/hasnans
# dropna
# fillna
# drop_duplicates
# drop
# apply
# isin
# corr
# nlargest -> nsmallest
# insert
# copy

# %%
# value_counts :

marks = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,12],
    [80,50,16],
    [80,50,16]
],columns=['iq','marks','package'])

marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       12
# 3   80     50       16
# 4   80     50       16

# %%
# value counts : ( series and Dataframes applicable)
marks.value_counts() # WE CAN COUNT THE FREQUENCY COUNT OF THE ROWS.\

# BUT IS MOSTLY USEFUL FOR SERIES.
# Out:
# iq   marks  package
# 80   50     16         2
# 100  80     10         1
# 90   70     7          1
# 120  100    12         1
# Name: count, dtype: int64

# %%
# find which player has won most potm -> in finals and qualiiers.

ipl = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/ipl-matches.csv')
ipl[~ipl['MatchNumber'].str.isdigit()].sample(10)['Player_of_Match']
# Out:
# 703        CH Gayle
# 705        SK Raina
# 0         HH Pandya
# 434         A Nehra
# 837    AC Gilchrist
# 74     F du Plessis
# 256      AD Russell
# 254       SR Watson
# 835        A Kumble
# 775        SK Raina
# Name: Player_of_Match, dtype: str

# %%
# toss decision plot :
ipl.sample(1)
# Out:
#          ID    City        Date Season MatchNumber          Team1  \
# 427  980911  Rajkot  2016-04-14   2016           6  Gujarat Lions
#
#                        Team2                                   Venue  \
# 427  Rising Pune Supergiants  Saurashtra Cricket Association Stadium
#
#                   TossWinner TossDecision SuperOver    WinningTeam    WonBy  \
# 427  Rising Pune Supergiants          bat         N  Gujarat Lions  Wickets
#
#      Margin method Player_of_Match  \
# 427     7.0    NaN        AJ Finch
#
#                                           Team1Players  \
# 427  ['AJ Finch', 'BB McCullum', 'SK Raina', 'DJ Br...
#
#                                           Team2Players      Umpire1    Umpire2
# 427  ['AM Rahane', 'F du Plessis', 'KP Pietersen', ...  VA Kulkarni  CK Nandan

# %%
import matplotlib as plt
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
# how many matches each team has played :
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Team1
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# **2. sort_values(series and dataframes)-> ascending -> na_position -> inplace -> multiple cols**

# %%
x = pd.Series([12,34,56,78,23])

# %%
x.sort_values(ascending=False)
# Out:
# 3    78
# 2    56
# 1    34
# 4    23
# 0    12
# dtype: int64

# %%
movies = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/movies.csv')
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
# 2             2019     112   Biography|Drama          6.1        5549
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
# 1  The story revolves around a cricket match betw...
# 2  Based on the memoir by Indian policy analyst S...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
# 1  The story of Battalion 609 revolves around a c...     NaN
# 2  Explores Manmohan Singh's tenure as the Prime ...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...              NaN
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...              NaN
#
#               release_date
# 0    11 January 2019 (USA)
# 1  11 January 2019 (India)
# 2    11 January 2019 (USA)

# %%
movies.sort_values(['title_x'],ascending=False).sample(10)
# Out:
#                        title_x    imdb_id  \
# 1035                  Yuvvraaj  tt1105747
# 1514                 Deewangee  tt0337971
# 1049                      Apne  tt0814014
# 1022             The Last Lear  tt1039969
# 1098  Loins of Punjab Presents  tt1012757
# 1150               Bhagam Bhag  tt0805184
# 828            Toh Baat Pakki!  tt1605778
# 1189     Pyaar Ke Side Effects  tt0480572
# 1528     Kabhie Tum Kabhie Hum  tt0367919
# 1581              Aśoka (film)  tt0249371
#
#                                             poster_path  \
# 1035  https://upload.wikimedia.org/wikipedia/en/thum...
# 1514  https://upload.wikimedia.org/wikipedia/en/thum...
# 1049  https://upload.wikimedia.org/wikipedia/en/thum...
# 1022  https://upload.wikimedia.org/wikipedia/en/thum...
# 1098  https://upload.wikimedia.org/wikipedia/en/thum...
# 1150  https://upload.wikimedia.org/wikipedia/en/thum...
# 828   https://upload.wikimedia.org/wikipedia/en/thum...
# 1189  https://upload.wikimedia.org/wikipedia/en/thum...
# 1528                                                NaN
# 1581  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1035             https://en.wikipedia.org/wiki/Yuvvraaj
# 1514            https://en.wikipedia.org/wiki/Deewangee
# 1049                 https://en.wikipedia.org/wiki/Apne
# 1022        https://en.wikipedia.org/wiki/The_Last_Lear
# 1098  https://en.wikipedia.org/wiki/Loins_of_Punjab_...
# 1150          https://en.wikipedia.org/wiki/Bhagam_Bhag
# 828       https://en.wikipedia.org/wiki/Toh_Baat_Pakki!
# 1189  https://en.wikipedia.org/wiki/Pyaar_Ke_Side_Ef...
# 1528  https://en.wikipedia.org/wiki/Kabhie_Tum_Kabhi...
# 1581    https://en.wikipedia.org/wiki/A%C5%9Boka_(film)
#
#                        title_y            original_title  is_adult  \
# 1035                  Yuvvraaj                  Yuvvraaj         0
# 1514                 Deewangee                 Deewangee         0
# 1049                      Apne                      Apne         0
# 1022             The Last Lear             The Last Lear         0
# 1098  Loins of Punjab Presents  Loins of Punjab Presents         0
# 1150               Bhagam Bhag               Bhagam Bhag         0
# 828            Toh Baat Pakki!           Toh Baat Pakki!         0
# 1189     Pyaar Ke Side Effects     Pyaar Ke Side Effects         0
# 1528     Kabhie Tum Kabhie Hum     Kabhie Tum Kabhie Hum         0
# 1581          Ashoka the Great                     Asoka         0
#
#       year_of_release runtime                   genres  imdb_rating  \
# 1035             2008     151     Comedy|Drama|Romance          4.1
# 1514             2002     169      Crime|Drama|Mystery          6.6
# 1049             2007     173              Drama|Sport          6.0
# 1022             2007     130                    Drama          7.0
# 1098             2007      88             Comedy|Music          7.0
# 1150             2006     157  Comedy|Mystery|Thriller          6.3
# 828              2010     122             Comedy|Drama          5.2
# 1189             2006     132     Comedy|Drama|Romance          6.7
# 1528             2002      \N      Comedy|Drama|Family          4.7
# 1581             2001     176   Action|Biography|Drama          6.5
#
#       imdb_votes                                              story  \
# 1035        3707  Yogendra Yuvvraaj Singh lives a wealthy lifest...
# 1514        2281  Raj is one of city's top lawyer known never to...
# 1049        2514  An ex-boxer Baldev Choudhary has had a stain i...
# 1022        1000  Film-maker Siddharth Kumar is receiving guests...
# 1098         749  A ruthless philantrophist. A bhangra rapper. A...
# 1150        9329  Champak Seth runs a theater group.Bunty and Ba...
# 828          339  After being asked to leave by his Palanpur-bas...
# 1189        2850  Bengal-speaking Siddharth Bose lives a middle-...
# 1528          13  A trip of a bank manager to a resort was spoil...
# 1581       12612  Prince Ashoke (Shahrukh Khan)  heir to the Mag...
#
#                                                 summary  \
# 1035  Two estranged brothers must learn to work toge...
# 1514  Raj is one of city's top lawyer known never to...
# 1049  A disgraced ex-boxer attempts to make his two ...
# 1022  An aging Shakespearean actor takes on one of t...
# 1098  A ruthless philantrophist. A bhangra rapper. A...
# 1150  The members of a drama troupe falls in trouble...
# 828   A pushy busybody invites a young man to be her...
# 1189  Bengal-speaking Siddharth Bose lives a middle-...
# 1528  A trip of a bank manager to a resort was spoil...
# 1581  The epic tale of King Asoka's life is recounte...
#
#                                       tagline  \
# 1035                         Music binds love
# 1514                                      NaN
# 1049                                      NaN
# 1022                                      NaN
# 1098  A comedy about life and other contests.
# 1150                                      NaN
# 828                                       NaN
# 1189        Watch love crash in this season .
# 1528                                      NaN
# 1581  Only the dead have seen the end of war.
#
#                                                  actors  \
# 1035  Salman Khan|Anil Kapoor|Zayed Khan|Mithun Chak...
# 1514  Ajay Devgn|Akshaye Khanna|Urmila Matondkar|Far...
# 1049  Dharmendra|Sunny Deol|Bobby Deol|Shilpa Shetty...
# 1022  Amitabh Bachchan|Preity Zinta|Arjun Rampal|She...
# 1098  Shabana Azmi|Ajay Naidu|Ayesha Dharker|Michael...
# 1150  Akshay Kumar|Govinda|Paresh Rawal|Lara Dutta|J...
# 828   Tabu|Sharman Joshi|Yuvika Chaudhry|Vatsal Shet...
# 1189  Rahul Bose|Mallika Sherawat|Ranvir Shorey|Shar...
# 1528  Mamta Kulkarni|Charuhas Shidore|Anjan Srivasta...
# 1581  Shah Rukh Khan|Kareena Kapoor|Danny Denzongpa|...
#
#              wins_nominations                   release_date
# 1035     1 win & 1 nomination         21 November 2008 (USA)
# 1514                   6 wins        25 October 2002 (India)
# 1049                      NaN             29 June 2007 (USA)
# 1022     1 win & 1 nomination        12 September 2008 (USA)
# 1098                      NaN  21 September 2007 (Indonesia)
# 1150                      NaN       22 December 2006 (India)
# 828                       NaN       19 February 2010 (India)
# 1189             1 nomination        15 September 2006 (USA)
# 1528                      NaN                            NaN
# 1581  2 wins & 17 nominations        26 October 2001 (India)

# %%
students = pd.DataFrame(
{
    'name': ['ritish', 'ankit', 'rupesh', np.nan, 'sunitanjay', np.nan, 'nishabh', np.nan, 'aditya', np.nan],
    'college': ['bit', 'iit', 'vit', np.nan, np.nan, 'vlsi', 'ssit', np.nan, np.nan, 'sit'],
    'branch': ['eee', 'it', 'cse', np.nan, np.nan, 'cse', 'bio', np.nan],
    'cgpa': [6.66, 8.25, 6.41, np.nan, 5.6, 9.0, 7.4, 10, 7.4, np.nan],
    'package': [4, 5, 6, np.nan, 6, 7, 8, 9, np.nan, np.nan]
}
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 students = pd.DataFrame(
#       2 {
#       3     'name': ['ritish', 'ankit', 'rupesh', np.nan, 'sunitanjay', np.nan, 'nishabh', np.nan, 'aditya', np.nan],
#       4     'college': ['bit', 'iit', 'vit', np.nan, np.nan, 'vlsi', 'ssit', np.nan, np.nan, 'sit'],
#       5     'branch': ['eee', 'it', 'cse', np.nan, np.nan, 'cse', 'bio', np.nan],
#       6     'cgpa': [6.66, 8.25, 6.41, np.nan, 5.6, 9.0, 7.4, 10, 7.4, np.nan],
#       7     'package': [4, 5, 6, np.nan, 6, 7, 8, 9, np.nan, np.nan]
#       8 }
#       9 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/internals/construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/internals/construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/internals/construction.py:643, in _extract_index(data)
#     641 if have_raw_arrays:
#     642     if len(raw_lengths) > 1:
# --> 643         raise ValueError("All arrays must be of the same length")
#     645     if have_dicts:
#     646         raise ValueError(
#     647             "Mixing dicts with non-Series may lead to ambiguous ordering."
#     648         )
#
# ValueError: All arrays must be of the same length
