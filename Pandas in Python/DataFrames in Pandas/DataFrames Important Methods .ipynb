# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **More Important Functions / methods :**

# %%
# value_counts
# sort_values
# rank
# sort_index
# set_index
# rename index -> rename
# reset_index
# unique & nunique
# isnull/notnull/hasnans
# dropna
# fillna
# drop_duplicates
# drop
# apply
# isin
# corr
# nlargest -> nsmallest
# insert
# copy

# %%
# value_counts :

marks = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,12],
    [80,50,16],
    [80,50,16]
],columns=['iq','marks','package'])

marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       12
# 3   80     50       16
# 4   80     50       16

# %%
# value counts : ( series and Dataframes applicable)
marks.value_counts() # WE CAN COUNT THE FREQUENCY COUNT OF THE ROWS.\

# BUT IS MOSTLY USEFUL FOR SERIES.
# Out:
# iq   marks  package
# 80   50     16         2
# 100  80     10         1
# 90   70     7          1
# 120  100    12         1
# Name: count, dtype: int64

# %%
# find which player has won most potm -> in finals and qualiiers.

ipl = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/ipl-matches.csv')
ipl[~ipl['MatchNumber'].str.isdigit()].sample(10)['Player_of_Match']
# Out:
# 552         KA Pollard
# 255        Rashid Khan
# 778         KA Pollard
# 194          JJ Bumrah
# 493           V Sehwag
# 703           CH Gayle
# 373        BCJ Cutting
# 196            RR Pant
# 629            M Vijay
# 316    NM Coulter-Nile
# Name: Player_of_Match, dtype: str

# %%
# toss decision plot :
ipl.sample(1)
# Out:
#          ID       City        Date   Season MatchNumber  \
# 825  419115  Bangalore  2010-03-18  2009/10          10
#
#                            Team1             Team2                  Venue  \
# 825  Royal Challengers Bangalore  Rajasthan Royals  M Chinnaswamy Stadium
#
#                       TossWinner TossDecision SuperOver  \
# 825  Royal Challengers Bangalore        field         N
#
#                      WinningTeam    WonBy  Margin method Player_of_Match  \
# 825  Royal Challengers Bangalore  Wickets    10.0    NaN       JH Kallis
#
#                                           Team1Players  \
# 825  ['MK Pandey', 'JH Kallis', 'RV Uthappa', 'V Ko...
#
#                                           Team2Players      Umpire1    Umpire2
# 825  ['NV Ojha', 'MJ Lumb', 'DR Martyn', 'AA Jhunjh...  K Hariharan  DJ Harper

# %%
import matplotlib as plt
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
# how many matches each team has played :
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Team1
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# **2. sort_values(series and dataframes)-> ascending -> na_position -> inplace -> multiple cols**

# %%
x = pd.Series([12,34,56,78,23])

# %%
x.sort_values(ascending=False)
# Out:
# 3    78
# 2    56
# 1    34
# 4    23
# 0    12
# dtype: int64

# %%
movies = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/movies.csv')
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
movies.sort_values(['title_x'],ascending=False).sample(10)
# Out:
#                                title_x    imdb_id  \
# 1047                 Anwar (2007 film)  tt0953306
# 1119  Salaam-e-Ishq: A Tribute to Love  tt0485272
# 1607           Nayak (2001 Hindi film)  tt0291376
# 1301  Taj Mahal: An Eternal Love Story  tt0328503
# 1232            Chetna: The Excitement  tt0487149
# 703                  Joker (2012 film)  tt1918886
# 504                         Filmistaan  tt2417560
# 102      Beyond the Clouds (2017 film)  tt3224288
# 1215    Tom Dick and Harry (2006 film)  tt0476888
# 12                           Hum Chaar  tt9319812
#
#                                             poster_path  \
# 1047  https://upload.wikimedia.org/wikipedia/en/thum...
# 1119  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 1301  https://upload.wikimedia.org/wikipedia/en/thum...
# 1232  https://upload.wikimedia.org/wikipedia/en/thum...
# 703   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
students = pd.DataFrame(
    {
        'name': ['ritish', 'ankit', 'rupesh', np.nan, 'sunitanjay', np.nan, 'nishabh', np.nan, 'aditya', np.nan],
        'college': ['bit', 'iit', 'vit', np.nan, np.nan, 'vlsi', 'ssit', np.nan, np.nan, 'sit'],
        'branch': ['eee', 'it', 'cse', np.nan, np.nan, 'cse', 'bio', np.nan, np.nan, np.nan],
        'cgpa': [6.66, 8.25, 6.41, np.nan, 5.6, 9.0, 7.4, 10, 7.4, np.nan],
        'package': [4, 5, 6, np.nan, 6, 7, 8, 9, np.nan, np.nan]
    }
)

students
# Out:
#          name college branch   cgpa  package
# 0      ritish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  sunitanjay     NaN    NaN   5.60      6.0
# 5         NaN    vlsi    cse   9.00      7.0
# 6     nishabh    ssit    bio   7.40      8.0
# 7         NaN     NaN    NaN  10.00      9.0
# 8      aditya     NaN    NaN   7.40      NaN
# 9         NaN     sit    NaN    NaN      NaN

# %%
students.sort_values('name', na_position='first', ascending=False,) 
# name column sorted and pushed the NaN values at the backside of the ranking.
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi    cse   9.00      7.0
# 7         NaN     NaN    NaN  10.00      9.0
# 9         NaN     sit    NaN    NaN      NaN
# 4  sunitanjay     NaN    NaN   5.60      6.0
# 2      rupesh     vit    cse   6.41      6.0
# 0      ritish     bit    eee   6.66      4.0
# 6     nishabh    ssit    bio   7.40      8.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    NaN   7.40      NaN

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      ritish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  sunitanjay     NaN    NaN   5.60      6.0
# 5         NaN    vlsi    cse   9.00      7.0
# 6     nishabh    ssit    bio   7.40      8.0
# 7         NaN     NaN    NaN  10.00      9.0
# 8      aditya     NaN    NaN   7.40      NaN
# 9         NaN     sit    NaN    NaN      NaN

# %%
movies.head(1)
movies.sort_values(['year_of_release', 'title_x'], ascending=[True,False])
# we can add multiple cols by using the list in sort values and we can also use ascending for mutiple cols by list.
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# **3. Rank(series):**

# %%
bats = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/batsman_runs_ipl.csv')
bats.sample(5)
# Out:
#               batter  batsman_run
# 120     CRD Fernando            4
# 137        DJ Harris          111
# 366  NM Coulter-Nile           82
# 113         CJ McKay            8
# 114    CK Kapugedera           16

# %%
bats['batsman_run'].rank(ascending=False)
# Out:
# 0      166.5
# 1      226.0
# 2      535.0
# 3      329.0
# 4      402.5
#        ...
# 600    594.0
# 601    343.0
# 602    547.5
# 603     27.0
# 604    256.0
# Name: batsman_run, Length: 605, dtype: float64

# %%
bats['batting_rank']= bats['batsman_run'].rank(ascending=False)
bats.sort_values('batting_rank')
# Out:
#              batter  batsman_run  batting_rank
# 569         V Kohli         6634           1.0
# 462        S Dhawan         6244           2.0
# 130       DA Warner         5883           3.0
# 430       RG Sharma         5881           4.0
# 493        SK Raina         5536           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh            0         594.0
# 63     Abdur Razzak            0         594.0
# 562          U Kaul            0         594.0
# 65       Akash Deep            0         594.0
# 57           AS Roy            0         594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# **4. sort_index() :(Series and Dataframes)**

# %%
marks = {
    'maths':89,
    'science':88,
    'English':67,
    'hindi':44
}

marks
# Out:
# {'maths': 89, 'science': 88, 'English': 67, 'hindi': 44}

# %%
marks_series = pd.Series(marks)
marks_series
# Out:
# maths      89
# science    88
# English    67
# hindi      44
# dtype: int64

# %%
marks_series.sort_index(ascending=False)
# Out:
# science    88
# maths      89
# hindi      44
# English    67
# dtype: int64

# %%
movies.sort_index(ascending=False).sample(7)
# Out:
#                       title_x    imdb_id  \
# 1103                   Naqaab  tt1020978
# 407               I Love Desi  tt4718678
# 731                 Dabangg 2  tt2112131
# 1607  Nayak (2001 Hindi film)  tt0291376
# 981           Golmaal Returns  tt1092005
# 476               Dishkiyaoon  tt3539966
# 336          Anna (2016 film)  tt6118134
#
#                                             poster_path  \
# 1103  https://upload.wikimedia.org/wikipedia/en/thum...
# 407   https://upload.wikimedia.org/wikipedia/en/thum...
# 731   https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 981   https://upload.wikimedia.org/wikipedia/en/thum...
# 476   https://upload.wikimedia.org/wikipedia/en/thum...
# 336   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link               title_y  \
# 1103               https://en.wikipedia.org/wiki/Naqaab                Naqaab
# ...

# %% [markdown]
# **5. Set_index(dataframe) -> inplace**

# %%
bats.set_index('batter', inplace=True)

# %% [markdown]
# **6. reset_index(series, dataframes) -> drop parameter**

# %%
bats.reset_index()  # this will reset the index again if we change it by using set index method.
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
bats.reset_index().set_index("batting_rank") # first reset then set the index.
# Out:
#                       batter  batsman_run
# batting_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
marks_series.reset_index()
# Out:
#      index   0
# 0    maths  89
# 1  science  88
# 2  English  67
# 3    hindi  44

# %%
type(marks_series.reset_index()) 
# it will change it to dataframe if we convert it again by using reset index.
# Out:
# pandas.DataFrame

# %% [markdown]
# **6. rename(dataframe) -> index :**

# %%
movies.set_index('title_x', inplace=True)

# %%
movies.rename(columns={'imdb_id' : 'imdb', 'poster_path':'link'}, inplace=True)
movies.head()
# Out:
#                                            imdb  \
# title_x
# Uri: The Surgical Strike              tt8291224
# Battalion 609                         tt9472208
# The Accidental Prime Minister (film)  tt6986710
# Why Cheat India                       tt8108208
# Evening Shadows                       tt6028796
#
#                                                                                    link  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# Why Cheat India                       https://upload.wikimedia.org/wikipedia/en/thum...
# Evening Shadows                                                                     NaN
#
#                                                                               wiki_link  \
# title_x
# ...

# %%
movies.rename(index={'Uri: The Surgical Strike':'Uri', 'Battalion 609':'Battalion'}).head()
# Out:
#                                            imdb  \
# title_x
# Uri                                   tt8291224
# Battalion                             tt9472208
# The Accidental Prime Minister (film)  tt6986710
# Why Cheat India                       tt8108208
# Evening Shadows                       tt6028796
#
#                                                                                    link  \
# title_x
# Uri                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion                                                                           NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# Why Cheat India                       https://upload.wikimedia.org/wikipedia/en/thum...
# Evening Shadows                                                                     NaN
#
#                                                                               wiki_link  \
# title_x
# ...

# %% [markdown]
# **7. unique(series):**

# %%
import numpy as np

# %%
temp = pd.Series([1,1,2,2,3,3,4,4,4,5,5,np.nan,np.nan])
print(temp)
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     2.0
# 4     3.0
# 5     3.0
# 6     4.0
# 7     4.0
# 8     4.0
# 9     5.0
# 10    5.0
# 11    NaN
# 12    NaN
# dtype: float64

# %%
temp.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5., nan])

# %%
len(ipl['Season'].unique())
# Out:
# 15

# %% [markdown]
# **8. nunique(series + dataframes) -> does not count nan -> dropna parameter**

# %%
ipl['Season'].nunique() # shows number of total unique values.
# nunique never count the unique values.
# Out:
# 15

# %% [markdown]
# **9. isnull(series, dataframes)**

# %%
students['name'][students['name'].isnull()]
# Out:
# 3    NaN
# 5    NaN
# 7    NaN
# 9    NaN
# Name: name, dtype: str

# %%
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True    True   True     True
# 4  False     True    True  False    False
# 5   True    False   False  False    False
# 6  False    False   False  False    False
# 7   True     True    True  False    False
# 8  False     True    True  False     True
# 9   True    False    True   True     True

# %% [markdown]
# **10. notnull(series + dataframes)**

# %%
students['name'][students['name'].notnull()]
# Out:
# 0        ritish
# 1         ankit
# 2        rupesh
# 4    sunitanjay
# 6       nishabh
# 8        aditya
# Name: name, dtype: str

# %%
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 0   True     True    True   True     True
# 1   True     True    True   True     True
# 2   True     True    True   True     True
# 3  False    False   False  False    False
# 4   True    False   False   True     True
# 5  False     True    True   True     True
# 6   True     True    True   True     True
# 7  False    False   False   True     True
# 8   True    False   False   True    False
# 9  False     True   False  False    False

# %% [markdown]
# **11. hasnans(series) :**

# %%
students['name'].hasnans # showing the missing value by saying True/ false.
# Out:
# True

# %% [markdown]
# **12. dropna(series + dataframes) -> how parameter -> works like or**

# %%
students['name'].dropna()
# Out:
# 0        ritish
# 1         ankit
# 2        rupesh
# 4    sunitanjay
# 6       nishabh
# 8        aditya
# Name: name, dtype: str

# %%
students.dropna() # removed all nan values ( missing values )
# Out:
#       name college branch  cgpa  package
# 0   ritish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  nishabh    ssit    bio  7.40      8.0

# %%
students.dropna(how='any') # we can control and adjust the dropna by using how=.
# and the default of dropna is always how='any'.
# Out:
#       name college branch  cgpa  package
# 0   ritish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  nishabh    ssit    bio  7.40      8.0

# %%
students.dropna(how='all') # only those rows will removed by how='all'.
# if they have all cols will be nan ( missing )
# 3 is removed only.
# Out:
#          name college branch   cgpa  package
# 0      ritish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 4  sunitanjay     NaN    NaN   5.60      6.0
# 5         NaN    vlsi    cse   9.00      7.0
# 6     nishabh    ssit    bio   7.40      8.0
# 7         NaN     NaN    NaN  10.00      9.0
# 8      aditya     NaN    NaN   7.40      NaN
# 9         NaN     sit    NaN    NaN      NaN

# %%
students.dropna(subset=['name']) # subset is use if want to remove the data by the column missing value
# Out:
#          name college branch  cgpa  package
# 0      ritish     bit    eee  6.66      4.0
# 1       ankit     iit     it  8.25      5.0
# 2      rupesh     vit    cse  6.41      6.0
# 4  sunitanjay     NaN    NaN  5.60      6.0
# 6     nishabh    ssit    bio  7.40      8.0
# 8      aditya     NaN    NaN  7.40      NaN

# %%
students.dropna(subset=['name', 'college']) # we can add one more value in subset.

# if we want permanet change in the dataset of dropna we use :
# inplace=True
# Out:
#       name college branch  cgpa  package
# 0   ritish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  nishabh    ssit    bio  7.40      8.0

# %% [markdown]
# **13. fillna(series + dataframes):**

# %%
students['name'].fillna('Unknown')
# Out:
# 0        ritish
# 1         ankit
# 2        rupesh
# 3       Unknown
# 4    sunitanjay
# 5       Unknown
# 6       nishabh
# 7       Unknown
# 8        aditya
# 9       Unknown
# Name: name, dtype: str

# %%
students['name'].fillna('Unknown').hasnans
# Out:
# False

# %%
students.fillna('Unknown') # dataframe
# Out:
#          name  college   branch     cgpa  package
# 0      ritish      bit      eee     6.66      4.0
# 1       ankit      iit       it     8.25      5.0
# 2      rupesh      vit      cse     6.41      6.0
# 3     Unknown  Unknown  Unknown  Unknown  Unknown
# 4  sunitanjay  Unknown  Unknown      5.6      6.0
# 5     Unknown     vlsi      cse      9.0      7.0
# 6     nishabh     ssit      bio      7.4      8.0
# 7     Unknown  Unknown  Unknown     10.0      9.0
# 8      aditya  Unknown  Unknown      7.4  Unknown
# 9     Unknown      sit  Unknown  Unknown  Unknown

# %%
students['package'].fillna(students['package'].mean())
# we give average value of the package column by mean.
# Out:
# 0    4.000000
# 1    5.000000
# 2    6.000000
# 3    6.428571
# 4    6.000000
# 5    7.000000
# 6    8.000000
# 7    9.000000
# 8    6.428571
# 9    6.428571
# Name: package, dtype: float64

# %%
# students['name'].fillna(method='ffill') old way
students['name'].ffill() # new way. 
# forward fillna method.
# Out:
# 0        ritish
# 1         ankit
# 2        rupesh
# 3        rupesh
# 4    sunitanjay
# 5    sunitanjay
# 6       nishabh
# 7       nishabh
# 8        aditya
# 9        aditya
# Name: name, dtype: str

# %%
# students['name'].fillna(method='bfill') old way
students['name'].bfill() # new way. 
# backward fillna method.
# Out:
# 0        ritish
# 1         ankit
# 2        rupesh
# 3    sunitanjay
# 4    sunitanjay
# 5       nishabh
# 6       nishabh
# 7        aditya
# 8        aditya
# 9           NaN
# Name: name, dtype: str

# %% [markdown]
# **14. drop_duplicates(Series + dataframes) -> works like and**

# %%
marks = pd.DataFrame([
    [100, 80, 10],
    [90, 70, 7],
    [120, 100, 14],
    [80, 70, 14],
    [80, 70, 14],
], columns=['iq', 'marks', 'package'])

marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
marks.duplicated().sum() # we found one duplicated value
# Out:
# np.int64(1)

# %%
marks.drop_duplicates()
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14

# %%
# find the last match played by virat kohli in delhi.
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['all_players']= ipl['Team1Players'] + ipl['Team2Players']
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
def did_kohli_play(player_list):
    return 'V kohli' in player_list

# %%
ipl['did_kohli_play']=ipl['all_players'].apply(did_kohli_play)
ipl[(ipl['City']=='Delhi')&(ipl['did_kohli_play']==True)].drop_duplicates(subset=['City', 'did_kohli_play'],keep='first')
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2, all_players, did_kohli_play]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# **15. drop(series + dataframes):**

# %%
temp = pd.Series([12,34,56,78,10,13,45,10]).astype('int8')
temp
# Out:
# 0    12
# 1    34
# 2    56
# 3    78
# 4    10
# 5    13
# 6    45
# 7    10
# dtype: int8

# %%
temp.drop(index=[4,7]) # we can use index for pointing which data we want to delete by using drop()
# Out:
# 0    12
# 1    34
# 2    56
# 3    78
# 5    13
# 6    45
# dtype: int8

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      ritish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  sunitanjay     NaN    NaN   5.60      6.0
# 5         NaN    vlsi    cse   9.00      7.0
# 6     nishabh    ssit    bio   7.40      8.0
# 7         NaN     NaN    NaN  10.00      9.0
# 8      aditya     NaN    NaN   7.40      NaN
# 9         NaN     sit    NaN    NaN      NaN

# %%
students.drop(columns=['branch', 'cgpa']) # we can also delete the cols.
# Out:
#          name college  package
# 0      ritish     bit      4.0
# 1       ankit     iit      5.0
# 2      rupesh     vit      6.0
# 3         NaN     NaN      NaN
# 4  sunitanjay     NaN      6.0
# 5         NaN    vlsi      7.0
# 6     nishabh    ssit      8.0
# 7         NaN     NaN      9.0
# 8      aditya     NaN      NaN
# 9         NaN     sit      NaN

# %%
students.drop(index=[0,8]) # can delete the drop index rows like that.
# Out:
#          name college branch   cgpa  package
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  sunitanjay     NaN    NaN   5.60      6.0
# 5         NaN    vlsi    cse   9.00      7.0
# 6     nishabh    ssit    bio   7.40      8.0
# 7         NaN     NaN    NaN  10.00      9.0
# 9         NaN     sit    NaN    NaN      NaN

# %% [markdown]
# **16. apply(series + dataframes):**

# %%
temp = pd.Series([10,20,30,40])
temp
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
def sigmoid(value):
    return 1/1+np.exp(-value)

# %%
temp.apply(sigmoid)
# Out:
# 0    1.000045
# 1    1.000000
# 2    1.000000
# 3    1.000000
# dtype: float64

# %%
points_df = pd.DataFrame(
    {
        '1st point': [(3,4), (-6,5), (0,0), (-10,1), (4,5)],
        '2nd point': [(-3,4), (0,0), (2,2), (10,10), (1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def euclidean(row):
    pt_a = row['1st point']
    pt_b = row['2nd point']

    return(pt_a[0] - pt_b[1]**2 + (pt_a[1] - pt_b[1])**2)**0.5

# %%
points_df['distance'] = points_df.apply(euclidean, axis=1)
points_df
# Out:
#   1st point 2nd point            distance
# 0    (3, 4)   (-3, 4)  0.000000+3.605551j
# 1   (-6, 5)    (0, 0)  4.358899+0.000000j
# 2    (0, 0)    (2, 2)  0.000000+0.000000j
# 3  (-10, 1)  (10, 10)  0.000000+5.385165j
# 4    (4, 5)    (1, 1)  4.358899+0.000000j
