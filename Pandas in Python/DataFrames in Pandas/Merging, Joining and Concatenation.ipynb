# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushmanz/Python-for-ML/blob/main/Pandas%20in%20Python/DataFrames%20in%20pandas/Merging%2C_Joining_and_Concatenation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
courses =pd.read_csv('/content/courses.csv')
delivery = pd.read_csv('/content/deliveries.csv')
matches = pd.read_csv('/content/matches.csv')
regm1 = pd.read_csv('/content/reg-month1.csv')
regm2 = pd.read_csv('/content/reg-month2.csv')
std = pd.read_csv('/content/students.csv')

# %%
regm2.shape
# Out:
# (28, 2)

# %%
# pd.concat
# df.concat
# ignore_index 
# df.append
# mullitindex -> fetch using iloc
# concat dataframes horizontally
