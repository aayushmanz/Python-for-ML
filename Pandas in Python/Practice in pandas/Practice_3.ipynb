# %%
import pandas as pd
import numpy as np

std = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/student_performance_finalscore.csv')
std.sample(5)
# Out:
#      Student_ID  Age  Gender  Hours_Studied  Attendance  Sleep_Hours  \
# 3883   STU03884   18  Female           5.01        79.6          6.4
# 2452   STU02453   23    Male           5.91        77.0          5.8
# 2472   STU02473   23  Female           2.32        79.4          7.9
# 4331   STU04332   22  Female           5.07        99.3          7.4
# 5905   STU05906   23  Female           8.44        95.2          8.5
#
#       Stress_Level  Screen_Time  Previous_GPA Part_Time_Job Study_Method  \
# 3883           5.7          4.4          3.24           Yes      Offline
# 2452           4.4          5.1          2.52            No      Offline
# 2472           3.3          3.9          2.16           Yes       Hybrid
# 4331           5.5          3.7          2.27           Yes       Hybrid
# 5905           6.5          3.1          3.14           Yes       Online
#
#      Diet_Quality Internet_Quality Extracurricular  \
# 3883      Average             Good              No
# ...

# %%
std['Student_ID'].count() # finding total students
# Out:
# np.int64(8000)

# %%
# total Non-binary students who are eligible of exams
std[(std['Attendance']>75)&(std['Gender']=="Non-Binary")].count()
std[(std['Attendance'] > 75) & (std['Gender'] == "Non-Binary") & (std['Study_Method'] == "Offline")].shape[0]
# Out:
# 61

# %%
# What is the average Final_Score and Previous_GPA of all the students in this dataset?

std_data = pd.read_csv("/workspaces/Python-for-ML/Database from Kaggle/student_performance_finalscore.csv")
std_data.sample(3)
# Out:
#      Student_ID  Age  Gender  Hours_Studied  Attendance  Sleep_Hours  \
# 3789   STU03790   19  Female           7.08        96.9          8.7
# 7891   STU07892   18    Male           5.32        74.5          6.5
# 5793   STU05794   18    Male           4.12        68.9          6.5
#
#       Stress_Level  Screen_Time  Previous_GPA Part_Time_Job Study_Method  \
# 3789           6.4          3.7          2.33            No      Offline
# 7891           3.9          3.1          3.89            No      Offline
# 5793           3.1          2.1          2.62            No       Online
#
#      Diet_Quality Internet_Quality Extracurricular  \
# 3789      Average          Average             Yes
# 7891      Average             Good             Yes
# 5793      Average          Average             Yes
#
#       Tutoring_Sessions_Per_Week Family_Income_Level  Exam_Anxiety_Score  \
# 3789                           0                High                 2.9
# ...

# %%
avg_previous = std_data['Previous_GPA'].mean()
avg_final = std_data['Final_Score'].mean()
print("The Final Year Average : " , avg_final)
print(f'The Previous Year Average : {avg_previous}')
# Out:
# The Final Year Average :  83.20564875
# The Previous Year Average : 2.9924075

# %%
# Which age group has the highest representation in the Age column?
std_data.sample()
# Out:
#      Student_ID  Age Gender  Hours_Studied  Attendance  Sleep_Hours  \
# 4241   STU04242   24   Male           4.22        64.2          6.7
#
#       Stress_Level  Screen_Time  Previous_GPA Part_Time_Job Study_Method  \
# 4241           5.4          2.8          2.87           Yes       Online
#
#      Diet_Quality Internet_Quality Extracurricular  \
# 4241         Good          Average             Yes
#
#       Tutoring_Sessions_Per_Week Family_Income_Level  Exam_Anxiety_Score  \
# 4241                           0                 Low                 3.5
#
#       Final_Score  Average_Previous_GPA
# 4241        77.95              2.992408

# %%
std_data.groupby("Age")['Age'].count().sort_values(ascending=False)
# Out:
# Age
# 18    1022
# 21    1016
# 23    1009
# 20     996
# 19     994
# 22     993
# 17     988
# 24     982
# Name: Age, dtype: int64

# %%
# Out of the available Study_Method options (Online, Offline, Hybrid), which one is most preferred by the students?
data = std_data.groupby("Study_Method")['Study_Method'].count().sort_values(ascending=False)
print("There are most of studnet Enrolled in : ",data.index[0])
print(f'Total Number of Studnets with {data.index[0]} is {data.iloc[0]}')
# Out:
# There are most of studnet Enrolled in :  Offline
# Total Number of Studnets with Offline is 3170

# %%
# Does an increase in Hours_Studied actually result in a higher Final_Score?
std_data.sample(6)
# Out:
#      Student_ID  Age  Gender  Hours_Studied  Attendance  Sleep_Hours  \
# 7767   STU07768   19  Female           4.30        75.9          5.0
# 4477   STU04478   24  Female           6.30        67.6          6.4
# 5475   STU05476   21  Female           5.47        81.4          7.2
# 1844   STU01845   24    Male           6.37        89.9          6.5
# 3590   STU03591   18  Female           4.28        87.3          4.2
# 4016   STU04017   24    Male           4.70        95.8          8.1
#
#       Stress_Level  Screen_Time  Previous_GPA Part_Time_Job Study_Method  \
# 7767           6.0          1.8          2.69            No       Hybrid
# 4477           4.6          5.6          2.39            No       Online
# 5475           3.4          3.1          2.88           Yes       Hybrid
# 1844           3.6          3.6          2.87           Yes      Offline
# 3590           4.5          3.1          2.94            No      Offline
# ...

# %%
corrilation = std_data['Hours_Studied'].corr(std_data['Final_Score'])
print(corrilation.astype('float32'))
# Out:
# 0.5913555

# %%
# Do students who maintain more than 80% Attendance score significantly better than the rest of the class?
high = std_data[std_data["Attendance"]>80.0]['Final_Score'].mean()
low =std_data[std_data['Final_Score']<=80.0]['Final_Score'].mean()

print(f'The High attendance std score : {high:.2f}')
print(f'The Lower attendance std score : {low:.2f}')
# Out:
# The High attendance std score : 84.90
# The Lower attendance std score : 68.23

# %%
# Is there a direct link between Exam_Anxiety_Score and Stress_Level? Do students with high stress end up getting lower marks?
a = std_data['Exam_Anxiety_Score'].corr(std_data['Final_Score'])
b = std_data['Stress_Level'].corr(std_data['Final_Score'])

print(f"The Answer for Exam_Anxiety_Score Student final Studnet : {a:.2f} ")
print(f"The Answer for Stress_Level Student final Studnet : {b:.2f} ")
# Out:
# The Answer for Exam_Anxiety_Score Student final Studnet : -0.49
# The Answer for Stress_Level Student final Studnet : -0.30

# %%
# Out:
# np.float64(79.933375)
