# %%
import pandas as pd
import numpy as np

std = pd.read_csv('/workspaces/Python-for-ML/Database from Kaggle/student_performance_finalscore.csv')
std.sample(5)
# Out:
#      Student_ID  Age  Gender  Hours_Studied  Attendance  Sleep_Hours  \
# 6488   STU06489   20    Male           5.29        66.0          9.7
# 4605   STU04606   18  Female           1.95        73.5          8.8
# 5775   STU05776   17    Male           1.18        66.9          7.6
# 770    STU00771   19    Male           5.38        55.9          9.4
# 2934   STU02935   19  Female           2.38        75.9          4.6
#
#       Stress_Level  Screen_Time  Previous_GPA Part_Time_Job Study_Method  \
# 6488           2.0          8.0          2.79            No      Offline
# 4605           5.0          2.7          2.88            No      Offline
# 5775           3.0          1.9          2.35           Yes       Hybrid
# 770            5.6          5.4          4.00           Yes       Hybrid
# 2934           6.8          2.3          3.13           Yes       Online
#
#      Diet_Quality Internet_Quality Extracurricular  \
# 6488      Average          Average              No
# 4605      Average             Good             Yes
# 5775         Poor             Good             Yes
# 770          Good        Excellent              No
# 2934      Average             Good              No
#
#       Tutoring_Sessions_Per_Week Family_Income_Level  Exam_Anxiety_Score  \
# 6488                           2                High                 5.5
# 4605                           1                High                 3.5
# 5775                           1              Middle                 6.1
# 770                            3              Middle                 5.1
# 2934                           0              Middle                 4.7
#
#       Final_Score
# 6488        82.18
# 4605        67.83
# 5775        45.50
# 770         89.63
# 2934        55.52

# %%
std['Student_ID'].count() # finding total students
# Out:
# np.int64(8000)

# %%
# total Non-binary students who are eligible of exams
std[(std['Attendance']>75)&(std['Gender']=="Non-Binary")].count()
std[(std['Attendance'] > 75) & (std['Gender'] == "Non-Binary") & (std['Study_Method'] == "Offline")].shape[0]
# Out:
# 61
